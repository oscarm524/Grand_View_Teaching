# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = [10, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700]
y = [0.43, 0.53, 0.58, 0.63, 0.67, 0.71, 0.73, 0.74, 0.75, 0.74, 0.75, 0.73, 0.74, 0.75, 0.74]

## Creating a new figure
plt.figure(figsize = (10, 8))

plt.plot(x, y)
plt.xlabel('Number of Trees')
plt.ylabel('F1-score')
plt.grid()
plt.show()
