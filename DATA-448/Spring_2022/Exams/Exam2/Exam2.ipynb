# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = [10, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 800, 900, 1000]
y = [0.43, 0.53, 0.58, 0.63, 0.67, 0.71, 0.73, 0.74, 0.75, 0.74, 0.75, 0.73, 0.74, 0.75, 0.74, 0.73, 0.74, 0.73]
w = [0.42, 0.51, 0.54, 0.57, 0.58, 0.57, 0.59, 0.61, 0.60, 0.62, 0.61, 0.60, 0.61, 0.59, 0.60, 0.62, 0.60, 0.61]

## Creating a new figure
plt.figure(figsize = (10, 8))

plt.plot(x, y, label = 'Train')
plt.plot(x, w, label = 'Test')
plt.xlabel('Number of Trees')
plt.ylabel('F1-score')
plt.title('Performance of Random Forest')
plt.grid()
plt.legend(loc = 'lower right')
# plt.savefig('plot1.pdf')
plt.show()
