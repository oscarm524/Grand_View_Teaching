# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from sklearn.neural_network import MLPRegressor

# Reading the csv
car_price = pd.read_csv('CarPrice_Assignment.csv')
car_price.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
X = car_price[['wheelbase', 'enginesize', 'compressionratio', 'horsepower', 'peakrpm', 'citympg']].copy()
Y = car_price['price']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
md1 = make_pipeline(MinMaxScaler(),
                    MLPRegressor(hidden_layer_sizes = (10,),
                                 activation = 'relu', 
                                 solver = 'adam', 
                                 max_iter = 100000,
                                 batch_size = 100)).fit(X_train, Y_train)

# Predicting on test
md1_pred = md1.predict(X_test)
md1_mse = mean_squared_error(Y_test, md1_pred)
print('The model 1 mse is', md1_mse)
# Out:
# The model 1 mse is 9457343.491188856
# /Users/oscaraguilar/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
md2 = make_pipeline(MinMaxScaler(),
                    MLPRegressor(hidden_layer_sizes = (10, 8),
                                 activation = 'relu', 
                                 solver = 'adam', 
                                 max_iter = 100000,
                                 batch_size = 100)).fit(X_train, Y_train)

# Predicting on test
md2_pred = md2.predict(X_test)
md2_mse = mean_squared_error(Y_test, md2_pred)
print('The model 2 mse is', md2_mse)
# Out:
# The model 2 mse is 9577060.797388034
