# %%
import pandas as pd 

## Reading the csv file 
customer_churn = pd.read_csv('Customer_Churn.csv')
customer_churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import numpy as np

## Changing lables to 0-1
customer_churn['Churn'] = np.where(customer_churn['Churn'] == 'No', 0, 1)
customer_churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import statsmodels.formula.api as smf

## Building the logistic regression model 
logit_md = smf.logit(formula = 'Churn ~ tenure + MonthlyCharges', data = customer_churn).fit()

## Extracting the model results
logit_md.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.453951
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                 7043
# Model:                          Logit   Df Residuals:                     7040
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 20 Oct 2021   Pseudo R-squ.:                  0.2154
# Time:                        19:28:20   Log-Likelihood:                -3197.2
# converged:                       True   LL-Null:                       -4075.1
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
## Defining the new observation
newdata = pd.DataFrame({'tenure': [20], 'MonthlyCharges': [80]})
newdata
# Out:
#    tenure  MonthlyCharges
# 0      20              80

# %%
## Predicting the likelihood of churning
logit_md.predict(newdata)
# Out:
# 0    0.434597
# dtype: float64
