# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

## setting the seed 
np.random.seed(805)

numb_samples = 1000
numb_obs = int(numb_samples / 4)

## Defining X and Y 
X = np.zeros((numb_samples, 2))
Y = np.zeros((numb_samples, ))

X[0:numb_obs, :] = np.random.multivariate_normal([1.0, -1.0], np.diag([0.1, 0.1]), size = numb_obs)
Y[0:numb_obs] = 0

X[numb_obs:(2*numb_obs), :] = np.random.multivariate_normal([1.0, 1.0], np.diag([0.1, 0.1]), size = numb_obs)
Y[numb_obs:(2*numb_obs)] = 1

X[(2*numb_obs):(3*numb_obs), :] = np.random.multivariate_normal([-1.0, 1.0], np.diag([0.1, 0.1]), size = numb_obs)
Y[(2*numb_obs):(3*numb_obs)] = 0

X[(3*numb_obs):, :] = np.random.multivariate_normal([-1.0, -1.0], np.diag([0.1, 0.1]), size = numb_obs)
Y[(3*numb_obs):] = 1

## Standardizing X
scaler = StandardScaler()
X = scaler.fit_transform(X)

X, Y = shuffle(X, Y, random_state = 805)

## Creating class colors
class_color = np.where(Y == 0, 'lighblue', 'orange')

fig = plt.figure(figsize = (10, 8))
plt.scatter(X[:, 0], X[:, 1])
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)
plt.xlabel('$X_0$')
plt.ylabel('$X_1$')
plt.grid()
plt.show()

# %%
class_color
# Out:
# array(['lighblue', 'lighblue', 'orange', 'lighblue', 'lighblue', 'orange',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'orange', 'lighblue', 'orange', 'lighblue', 'lighblue', 'lighblue',
#        'orange', 'lighblue', 'orange', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'orange', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'orange',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'orange', 'lighblue', 'orange', 'orange',
#        'lighblue', 'orange', 'lighblue', 'orange', 'orange', 'orange',
#        'lighblue', 'orange', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'lighblue', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'lighblue', 'orange',
#        'orange', 'orange', 'orange', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'orange', 'lighblue', 'orange', 'lighblue', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange', 'orange',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'orange', 'orange', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'orange', 'lighblue', 'orange', 'orange', 'orange',
#        'orange', 'lighblue', 'orange', 'lighblue', 'orange', 'orange',
#        'orange', 'orange', 'lighblue', 'orange', 'orange', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'lighblue',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'lighblue',
#        'lighblue', 'orange', 'lighblue', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'orange', 'orange', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'orange', 'orange', 'orange', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'orange', 'orange', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'orange',
#        'orange', 'lighblue', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'orange', 'orange', 'orange', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'lighblue',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'orange',
#        'orange', 'lighblue', 'lighblue', 'lighblue', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'lighblue', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'orange', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'lighblue', 'lighblue',
#        'lighblue', 'orange', 'lighblue', 'orange', 'orange', 'orange',
#        'orange', 'lighblue', 'lighblue', 'orange', 'orange', 'orange',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'orange', 'orange', 'lighblue', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'orange', 'lighblue', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'lighblue', 'orange',
#        'orange', 'orange', 'lighblue', 'orange', 'lighblue', 'orange',
#        'orange', 'lighblue', 'orange', 'orange', 'orange', 'orange',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'lighblue',
#        'orange', 'orange', 'lighblue', 'orange', 'lighblue', 'orange',
#        'orange', 'orange', 'lighblue', 'orange', 'lighblue', 'orange',
#        'orange', 'lighblue', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'orange', 'lighblue', 'lighblue', 'orange', 'orange',
#        'lighblue', 'lighblue', 'orange', 'orange', 'lighblue', 'lighblue',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'orange', 'orange', 'orange', 'lighblue', 'orange', 'orange',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'lighblue',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'orange',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'orange',
#        'lighblue', 'orange', 'lighblue', 'orange', 'orange', 'orange',
#        'orange', 'lighblue', 'orange', 'orange', 'orange', 'lighblue',
#        'lighblue', 'orange', 'lighblue', 'lighblue', 'orange', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange', 'orange',
#        'orange', 'orange', 'lighblue', 'orange', 'orange', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'orange', 'orange', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'lighblue', 'orange',
#        'orange', 'orange', 'orange', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'orange', 'orange', 'orange', 'orange', 'lighblue',
#        'lighblue', 'orange', 'orange', 'lighblue', 'orange', 'orange',
#        'orange', 'orange', 'lighblue', 'orange', 'lighblue', 'orange',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'orange', 'lighblue', 'orange', 'orange', 'orange', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'lighblue', 'orange',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'lighblue',
#        'orange', 'lighblue', 'orange', 'lighblue', 'orange', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'orange', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'orange',
#        'lighblue', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'lighblue', 'orange', 'lighblue', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'lighblue',
#        'orange', 'orange', 'orange', 'lighblue', 'orange', 'orange',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'orange', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'lighblue', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'orange', 'lighblue', 'lighblue', 'lighblue', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'lighblue', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'orange', 'orange',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'lighblue',
#        'orange', 'orange', 'orange', 'lighblue', 'lighblue', 'orange',
#        'orange', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'orange',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'orange',
#        'orange', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'orange', 'lighblue', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'lighblue', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'orange', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'lighblue',
#        'orange', 'orange', 'lighblue', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'lighblue',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'orange', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'orange', 'orange', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'orange', 'orange', 'orange', 'orange', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'lighblue', 'lighblue', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'lighblue',
#        'orange', 'orange', 'orange', 'lighblue', 'orange', 'lighblue',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'orange', 'lighblue', 'orange', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange', 'orange',
#        'lighblue', 'lighblue', 'orange', 'orange', 'orange', 'lighblue',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'orange', 'orange',
#        'lighblue', 'lighblue', 'orange', 'orange', 'lighblue', 'orange',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'orange',
#        'lighblue', 'orange', 'lighblue', 'orange', 'orange', 'lighblue',
#        'lighblue', 'orange', 'orange', 'lighblue', 'lighblue', 'lighblue',
#        'lighblue', 'orange', 'orange', 'lighblue', 'orange', 'lighblue',
#        'orange', 'lighblue', 'lighblue', 'orange', 'lighblue', 'orange',
#        'lighblue', 'lighblue', 'lighblue', 'lighblue', 'lighblue',
#        'orange', 'lighblue'], dtype='<U8')
