# %%
import boto3
import pandas as pd; pd.set_option('display.max_columns', 100)
import numpy as np

s3 = boto3.resource('s3')
bucket_name = 'data-445'
bucket = s3.Bucket(bucket_name)

file_key = 'framingham.csv'

bucket_object = bucket.Object(file_key)
file_object = bucket_object.get()
file_content_stream = file_object.get('Body')

# Reading the data-file
heart = pd.read_csv(file_content_stream)
heart.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
# ...

# %%
heart.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %%
## Dropping observations with missing values
heart = heart.dropna()

# %%
import matplotlib.pyplot as plt

plt.scatter(x = 'BMI', y = 'heartRate', data = heart)
plt.xlabel('BMI')
plt.ylabel('Heart Rate')
plt.show();

# %%
# From the above plot, we don't any obvious relationship between BMI and heartRate

# %%
plt.scatter(x = 'glucose', y = 'BMI', data = heart)
plt.xlabel('glucose')
plt.ylabel('BMI')
plt.show();

# %%
# From the above plot, it seems that there two groups in the data. And in one of them, 
# the relationship between glucose and heartRate seems to positive/exponential.

# %%
from sklearn.linear_model import LogisticRegression

## Defining the input and target variables
X = heart[['age', 'currentSmoker', 'totChol', 'BMI', 'heartRate']]
Y = heart['TenYearCHD']

## Building the logistic regression model
logit_md = LogisticRegression().fit(X, Y)

## Extacting the estimated coefficients
logit_md.coef_
# Out:
# array([[0.08029144, 0.49327195, 0.00227601, 0.04200999, 0.00239242]])

# %%
## Predicting the likelihood 
logit_md.predict_proba([[50, 1, 250, 27, 85]])
# Out:
# array([[0.8193106, 0.1806894]])
