# %%
import pandas as pd 
import numpy as np

# Reading the csv file 
goalie_stats = pd.read_csv('game_goalie_stats.csv')
goalie_stats.head()
# Out:
#       game_id  player_id  team_id  timeOnIce  assists  goals  pim  shots  \
# 0  2012030221    8468685        3       4540        0      0    0     48
# 1  2012030221    8471695        6       4540        0      0    0     35
# 2  2012030222    8468685        3       3600        0      0    0     32
# 3  2012030222    8471695        6       3600        0      0    0     37
# 4  2012030223    8471695        6       3600        0      0    0     24
#
#    saves  powerPlaySaves  shortHandedSaves  evenSaves  \
# 0     45              10                 1         34
# 1     33               3                 0         30
# 2     27               1                 2         24
# 3     35               7                 1         27
# 4     23               2                 0         21
#
#    shortHandedShotsAgainst  evenShotsAgainst  powerPlayShotsAgainst decision  \
# 0                        1                36                     11        L
# ...

# %%
# Printing the first four observations
goalie_stats.head(4)
# Out:
#       game_id  player_id  team_id  timeOnIce  assists  goals  pim  shots  \
# 0  2012030221    8468685        3       4540        0      0    0     48
# 1  2012030221    8471695        6       4540        0      0    0     35
# 2  2012030222    8468685        3       3600        0      0    0     32
# 3  2012030222    8471695        6       3600        0      0    0     37
#
#    saves  powerPlaySaves  shortHandedSaves  evenSaves  \
# 0     45              10                 1         34
# 1     33               3                 0         30
# 2     27               1                 2         24
# 3     35               7                 1         27
#
#    shortHandedShotsAgainst  evenShotsAgainst  powerPlayShotsAgainst decision  \
# 0                        1                36                     11        L
# 1                        0                32                      3        W
# 2                        2                29                      1        L
# ...

# %%
# Printing the last four observations
goalie_stats.tail(4)
# Out:
#           game_id  player_id  team_id  timeOnIce  assists  goals  pim  shots  \
# 16058  2017020726    8473541       21       3600        0      0    0     31
# 16059  2017020726    8475883       10       3479        0      0    0     26
# 16060  2016020251    8473575       21       3543        0      0    0     22
# 16061  2016020251    8470140       25       3600        0      0    0     36
#
#        saves  powerPlaySaves  shortHandedSaves  evenSaves  \
# 16058     29               3                 0         26
# 16059     23               0                 1         22
# 16060     19               2                 0         17
# 16061     34               3                 4         27
#
#        shortHandedShotsAgainst  evenShotsAgainst  powerPlayShotsAgainst  \
# 16058                        0                28                      3
# 16059                        1                25                      0
# ...

# %%
# Reporting the number of team ids
goalie_stats['team_id'].nunique()
# Out:
# 32

# %%
goalie_stats[(goalie_stats['decision'] == 'W') & (goalie_stats['savePercentage'] > 95)]['player_id'].nunique()
# Out:
# 125
