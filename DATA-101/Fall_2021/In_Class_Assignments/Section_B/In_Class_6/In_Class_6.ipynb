# %%
import pandas as pd

## Reading csv file 
Index = pd.read_csv('Index.csv')
Index.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
## Creating a bar chart of gender
Index['Gender'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
## Based on the above bar-chart we see that the female bar is a little taller than the male bar.

# %%
## Creating a histogram of Height
Index['Height'].hist()
# Out:
# <AxesSubplot:>

# %%
## The histogram has to two peaks: one around 165 and another one around 185.

# %%
import matplotlib.pyplot as plt 

## Creating the scatter plot 
plt.plot(Index['Height'], Index['Weight'],'o')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.grid()
plt.show()

# %%
## From the above plot, there is not a clear relationship between height and weight.
